# %%
import pandas as pd

# Load the uploaded CSV file
file_path = "/content/spend_analysis_dataset.csv"
df = pd.read_csv(file_path)

# Display basic information and the first few rows of the dataset
df.info(), df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   TransactionID  500 non-null    object
#  1   ItemName       500 non-null    object
#  2   Category       500 non-null    object
#  3   Quantity       500 non-null    int64
#  4   UnitPrice      500 non-null    float64
#  5   TotalCost      500 non-null    float64
#  6   PurchaseDate   500 non-null    object
#  7   Supplier       500 non-null    object
#  8   Buyer          500 non-null    object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 35.3+ KB
# (None,
#    TransactionID                 ItemName         Category  Quantity  \
#  0        TXN001               Desk Chair        Furniture        10
#  1        TXN002                  Stapler  Office Supplies        16
#  2        TXN003  Annual Software License         Software         1
# ...

# %%
# Q1: Total spending by category
category_spend = df.groupby('Category')['TotalCost'].sum() # Calculate total spending per category
plt.figure()
category_spend.plot(kind='bar', title='Total Spending by Category', ylabel='Total Spend')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Q2: Monthly trend in total spending
plt.figure()
sns.lineplot(data=monthly_trend, x='Month', y='TotalCost', marker='o')
plt.title('Monthly Trend in Total Spending')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Q3: Top 10 items by average cost per unit
avg_unit_price = df.groupby('ItemName')['UnitPrice'].mean().sort_values(ascending=False).head(10)
plt.figure()
avg_unit_price.plot(kind='bar', title='Top 10 Items by Avg Cost per Unit', ylabel='Average Unit Price')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Q4: Total spend per supplier
# Calculate total spend per supplier and assign it to spend_per_supplier
spend_per_supplier = df.groupby('Supplier')['TotalCost'].sum()
plt.figure()
spend_per_supplier.plot(kind='bar', title='Total Spend per Supplier', ylabel='Total Spend')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Q5: Total spend per buyer
spend_per_buyer = df.groupby('Buyer')['TotalCost'].sum()  # Calculate total spend per buyer and assign it to spend_per_buyer
plt.figure()
spend_per_buyer.plot(kind='bar', title='Total Spend per Buyer', ylabel='Total Spend')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Q6: Unique items per buyer
plt.figure()
unique_items_per_buyer.sort_values('ItemName', ascending=False).set_index('Buyer').plot(kind='bar', legend=False)
plt.title('Unique Items Purchased Per Buyer')
plt.ylabel('Unique Items')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Q7: Buyer with most transactions
transactions_per_buyer = df['Buyer'].value_counts()  # Calculate transactions per buyer and assign to transactions_per_buyer
plt.figure()
transactions_per_buyer.plot(kind='bar', title='Number of Transactions per Buyer', ylabel='Transactions')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Q8: Avg transaction value per supplier
# Calculate average transaction value per supplier
avg_transaction_supplier = df.groupby('Supplier')['TotalCost'].mean()

plt.figure()
avg_transaction_supplier.plot(kind='bar', title='Avg Transaction Value per Supplier', ylabel='Average Transaction Value')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Q9: Buyers per supplier
plt.figure()
buyers_per_supplier.set_index('Supplier').sort_values('Buyer', ascending=False).plot(kind='bar', legend=False)
plt.title('Number of Unique Buyers per Supplier')
plt.ylabel('Number of Buyers')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Q10: Most frequently purchased items (top 10)
item_counts = df['ItemName'].value_counts().head(10) # Calculate item counts and assign to item_counts
plt.figure()
item_counts.plot(kind='bar', title='Top 10 Most Frequently Purchased Items', ylabel='Purchase Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Q11: Number of transactions per category
transactions_per_category = df['Category'].value_counts()  # Calculate transactions per category and assign to transactions_per_category
plt.figure()
transactions_per_category.plot(kind='bar', title='Number of Transactions per Category', ylabel='Transactions')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Q12: Average cost per item in each category
# Calculate average cost per item in each category and assign it to avg_cost_item_category
avg_cost_item_category = (df.groupby('Category')['TotalCost'].sum() / df.groupby('Category')['Quantity'].sum()).reset_index(name='AvgCostPerItem')

plt.figure()
avg_cost_item_category.plot(kind='bar', x='Category', y='AvgCostPerItem', title='Avg Cost per Item in Each Category', ylabel='Average Cost') # Specify x and y columns for the plot
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
